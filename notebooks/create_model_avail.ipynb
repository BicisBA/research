# %%
import duckdb
import pyarrow.dataset as ds
import pandas as pd

# %%
dataset = ds.dataset("data/status", format="parquet", partitioning="hive")

# %%
dataset.count_rows()
# Out:
# 382286723

# %%
con = duckdb.connect()
con = con.register("status", dataset)

# %%
schema_df = con.execute(
    """
    describe status"""
).df()

# %%
schema_df
# Out:
#                   column_name                              column_type null  \
# 0         is_charging_station                                  BOOLEAN  YES
# 1                is_installed                                   BIGINT  YES
# 2                  is_renting                                   BIGINT  YES
# 3                is_returning                                   BIGINT  YES
# 4               last_reported                                   BIGINT  YES
# 5         num_bikes_available                                   BIGINT  YES
# 6   num_bikes_available_types  STRUCT(ebike BIGINT, mechanical BIGINT)  YES
# 7          num_bikes_disabled                                   BIGINT  YES
# 8         num_docks_available                                   BIGINT  YES
# 9          num_docks_disabled                                   BIGINT  YES
# 10                 station_id                                  INTEGER  YES
# 11                     status                                  VARCHAR  YES
# 12                     minute                                  INTEGER  YES
# 13                       year                                  INTEGER  YES
# 14                      month                                  INTEGER  YES
# 15                        day                                  INTEGER  YES
# 16                       hour                                  INTEGER  YES
#
#     key default  extra
# 0   NaN     NaN    NaN
# 1   NaN     NaN    NaN
# 2   NaN     NaN    NaN
# 3   NaN     NaN    NaN
# 4   NaN     NaN    NaN
# 5   NaN     NaN    NaN
# 6   NaN     NaN    NaN
# 7   NaN     NaN    NaN
# 8   NaN     NaN    NaN
# 9   NaN     NaN    NaN
# 10  NaN     NaN    NaN
# 11  NaN     NaN    NaN
# 12  NaN     NaN    NaN
# 13  NaN     NaN    NaN
# 14  NaN     NaN    NaN
# 15  NaN     NaN    NaN
# 16  NaN     NaN    NaN

# %%
duckdf = con.execute(
    """
    select
        make_timestamp(year, month, day, hour, minute, 0.0) as ts,
        station_id,
        hour,
        minute,
        dayofweek(make_timestamp(year, month, day, hour, minute, 0.0)) as dow,
        num_bikes_available,
        num_bikes_disabled,
        num_docks_available,
        num_docks_disabled,
        minute(lead(make_timestamp(year, month, day, hour, minute, 0.0), 5) over (
            partition by station_id
            order by make_timestamp(year, month, day, hour, minute, 0.0) asc
        ) - make_timestamp(year, month, day, hour, minute, 0.0))  as minutes_bt_check,
        lead(num_bikes_available, 5) over (
            partition by station_id
            order by make_timestamp(year, month, day, hour, minute, 0.0) asc
        ) as bikes_available,
    from
        status
    where
        month > 1 and
        station_id = 3 and
        status = 'IN_SERVICE' and
        year = 2022"""
).df()
duckdf.head()
# Out:
#                    ts  station_id  hour  minute  dow  num_bikes_available  \
# 0 2022-02-01 00:00:00           3     0       0    2                    0
# 1 2022-02-01 00:01:00           3     0       1    2                    0
# 2 2022-02-01 00:02:00           3     0       2    2                    0
# 3 2022-02-01 00:03:00           3     0       3    2                    0
# 4 2022-02-01 00:04:00           3     0       4    2                    0
#
#    num_bikes_disabled  num_docks_available  num_docks_disabled  \
# 0                   1                   19                   0
# 1                   1                   19                   0
# 2                   1                   19                   0
# 3                   1                   19                   0
# 4                   1                   19                   0
#
#    minutes_bt_check  bikes_available
# 0               5.0              0.0
# 1               5.0              0.0
# 2               5.0              0.0
# 3               5.0              0.0
# 4               5.0              0.0

# %%
len(duckdf)
# Out:
# 377083

# %% [markdown]
# # Prophet

# %%
from prophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
duckdf['ds'] = duckdf['ts']
duckdf['y'] = duckdf['num_bikes_available']

duckdf['floor'] = 0
duckdf['cap'] = duckdf['num_docks_available'] + duckdf['num_bikes_available']
# m = Prophet(growth='logistic')
# m.fit(duckdf[duckdf["ds"]< '2022-03-01' ][["ds", "y", "floor", "cap"]])
m = Prophet()
m.fit(duckdf[(duckdf["ds"] >= '2022-05-01') & (duckdf["ds"] < '2022-08-01')][["ds", "y"]])
# Out:
# 11:57:13 - cmdstanpy - INFO - Chain [1] start processing
# 11:59:40 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=15, freq='H')
fcst = m.predict(future)
fig = m.plot(fcst)

# %%
fig = m.plot_components(fcst);

# %%
fcst = m.predict(duckdf[(duckdf["ds"] >= '2022-08-01') & (duckdf["ds"] < '2022-09-01')][["ds", "y"]])

# %%
fcst["y"] = duckdf[(duckdf["ds"] >= '2022-08-01') & (duckdf["ds"] < '2022-09-01')]["y"].values

# %%
fcst["bike_a_pred"] = fcst["yhat"]>0
fcst["bike_a"] = fcst["y"]>0
fcst[["bike_a", "bike_a_pred"]]
len(fcst[fcst["bike_a"] == fcst["bike_a_pred"]]) / len(fcst)
# Out:
# 0.854831118183652

# %%
len(fcst[(fcst["bike_a"] == fcst["bike_a_pred"]) & (fcst["bike_a"] == False)]) / len(fcst[fcst["bike_a"] == False])
# Out:
# 0.0

# %% [markdown]
# Es un buen estimador de cuantas bicis va a haber en un momento dado, pero un mal predictor para saber si va a haber bicis o no.

# %% [markdown]
# # Random forest a 5 min

# %%
train_set = duckdf[(duckdf["ts"] >= '2022-05-01') & (duckdf["ts"] < '2022-08-01')][["num_bikes_available", "hour", "dow"]]

# %%
train_set["avail_1_min"] = train_set["num_bikes_available"].shift(1)
train_set = train_set.dropna()

# %%
train_set.head()
# Out:
#         num_bikes_available  hour  dow  avail_1_min
# 112985                    6     0    0          6.0
# 112986                    6     0    0          6.0
# 112987                    6     0    0          6.0
# 112988                    6     0    0          6.0
# 112989                    6     0    0          6.0

# %%
test_set = duckdf[(duckdf["ts"] >= '2022-08-01') & (duckdf["ts"] < '2022-09-01')][["num_bikes_available", "hour", "dow", "bikes_available"]]

# %%
test_set["bike_a_pred"] = test_set["num_bikes_available"]>0
test_set["bike_a"] = test_set["bikes_available"]>0
(len(test_set[test_set["bike_a"] == test_set["bike_a_pred"]]) / len(test_set),
len(test_set[(test_set["bike_a"] == test_set["bike_a_pred"]) & (test_set["bike_a"] == False)]) / len(test_set[test_set["bike_a"] == False]))
# Out:
# (0.9794248828921711, 0.9291338582677166)

# %% [markdown]
# Predecir el mismo estado en 5 minutos da un 97.9% de precision, y un 92,9% en los casos q no hay bicicletas.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix

# %%
rf_pipe = make_pipeline(ColumnTransformer([("ohe",  OneHotEncoder(), ["hour", "dow"])], remainder="passthrough"), RandomForestRegressor())

# %%
rf_pipe.fit(train_set[["num_bikes_available", "hour", "dow"]], train_set["avail_1_min"])
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe', OneHotEncoder(),
#                                                   ['hour', 'dow'])])),
#                 ('randomforestregressor', RandomForestRegressor())])

# %%
test_set["num_bikes_available_0"] = test_set["num_bikes_available"]
for i in range(1,6):
    test_set["p"+str(i)] = rf_pipe.predict(test_set[["num_bikes_available", "hour", "dow"]])
    test_set["num_bikes_available"] = test_set["p"+str(i)]
test_set["num_bikes_available"] = test_set["num_bikes_available_0"]
del test_set["num_bikes_available_0"]

# %%
test_set["bike_a_pred"] = test_set["p5"]>=1
test_set["bike_a"] = test_set["bikes_available"]>0
test_set[["bike_a", "bike_a_pred"]]
(len(test_set[test_set["bike_a"] == test_set["bike_a_pred"]]) / len(test_set),
len(test_set[(test_set["bike_a"] == test_set["bike_a_pred"]) & (test_set["bike_a"] == False)]) / len(test_set[test_set["bike_a"] == False]))
# Out:
# (0.951610372727884, 0.8923884514435696)

# %%
test_set.tail()
# Out:
#         num_bikes_available  hour  dow  bikes_available  bike_a_pred  bike_a  \
# 289871                    3    23    3              3.0         True    True
# 289872                    3    23    3              3.0         True    True
# 289873                    3    23    3              3.0         True    True
# 289874                    3    23    3              3.0         True    True
# 289875                    3    23    3              3.0         True    True
#
#               p1        p2        p3        p4        p5
# 289871  3.019783  3.019783  3.019783  3.019783  3.019783
# 289872  3.019783  3.019783  3.019783  3.019783  3.019783
# 289873  3.019783  3.019783  3.019783  3.019783  3.019783
# 289874  3.019783  3.019783  3.019783  3.019783  3.019783
# 289875  3.019783  3.019783  3.019783  3.019783  3.019783

# %%
sorted(list(zip(rf_pipe["columntransformer"].get_feature_names_out(), rf_pipe["randomforestregressor"].feature_importances_)),
        key= lambda x: x[1],reverse=True
)[:10]
# Out:
# [('remainder__num_bikes_available', 0.999832149007385),
#  ('ohe__dow_4', 2.03979981981516e-05),
#  ('ohe__dow_5', 1.5162801778448611e-05),
#  ('ohe__dow_3', 1.4317942137022796e-05),
#  ('ohe__dow_2', 1.3669147147696345e-05),
#  ('ohe__dow_1', 1.2541785510521641e-05),
#  ('ohe__dow_0', 1.1530537515543412e-05),
#  ('ohe__hour_9', 9.069575335532109e-06),
#  ('ohe__hour_16', 7.0062561647068456e-06),
#  ('ohe__hour_8', 5.373549119659723e-06)]

# %% [markdown]
# Usar un random forest performa peor que el modelo base, y usa como principal feature el numero de bicicletas actuales.

# %% [markdown]
# # Usar minutos como feature

# %% [markdown]
# El foco del modelo es no enviar a un usuario a buscar una bicicleta cuando no este disponible, osea la tasa de falsos postivos.
#
# Para mejorar la tasa de falsos positivos vamos a usar pesos por clases en las muestras durante el entrenamiento.

# %%
dfs_to_concat = []
for i in range(1,16):
    auxdf = con.execute(
        f"""
        select
            make_timestamp(year, month, day, hour, minute, 0.0) as ts,
            station_id,
            hour,
            minute,
            dayofweek(make_timestamp(year, month, day, hour, minute, 0.0)) as dow,
            num_bikes_available,
            num_bikes_disabled,
            num_docks_available,
            num_docks_disabled,
            minute(lead(make_timestamp(year, month, day, hour, minute, 0.0), {i}) over (
                partition by station_id
                order by make_timestamp(year, month, day, hour, minute, 0.0) asc
            ) - make_timestamp(year, month, day, hour, minute, 0.0))  as minutes_bt_check,
            lead(num_bikes_available, {i}) over (
                partition by station_id
                order by make_timestamp(year, month, day, hour, minute, 0.0) asc
            ) as bikes_available,
        from
            status
        where
            (month = 3 or month = 4) and
            station_id = 3 and
            status = 'IN_SERVICE' and
            year = 2022"""
    ).df()
    dfs_to_concat.append(auxdf)
mins_df = pd.concat(dfs_to_concat)
del dfs_to_concat
mins_df["bikes_a"] = mins_df["bikes_available"] > 0
mins_df.head()
# Out:
#                    ts  station_id  hour  minute  dow  num_bikes_available  \
# 0 2022-03-01 01:23:00           3     1      23    2                    1
# 1 2022-03-01 01:24:00           3     1      24    2                    1
# 2 2022-03-01 01:25:00           3     1      25    2                    1
# 3 2022-03-01 01:39:00           3     1      39    2                    1
# 4 2022-03-01 01:41:00           3     1      41    2                    1
#
#    num_bikes_disabled  num_docks_available  num_docks_disabled  \
# 0                   1                   18                   0
# 1                   1                   18                   0
# 2                   1                   18                   0
# 3                   1                   18                   0
# 4                   1                   18                   0
#
#    minutes_bt_check  bikes_available  bikes_a
# 0               1.0              1.0     True
# 1               1.0              1.0     True
# 2              14.0              1.0     True
# 3               2.0              1.0     True
# 4               3.0              1.0     True

# %%
len(mins_df), len(mins_df[mins_df["bikes_a"] == False])/len(mins_df)
# Out:
# (1251675, 0.2534363952303913)

# %%
train_set = mins_df[mins_df["ts"] < '2022-04-9']
val_set = mins_df[(mins_df["ts"] >= '2022-04-9') & (mins_df["ts"] < '2022-04-17')]
test_set = mins_df[mins_df["ts"] >= '2022-04-17']
len(train_set), len(val_set), len(test_set)
# Out:
# (785085, 164235, 302355)

# %%
test_set["bikes_a_pred"] = test_set["num_bikes_available"]>0
(len(test_set[test_set["bikes_a"] == test_set["bikes_a_pred"]]) / len(test_set),
len(test_set[(test_set["bikes_a"] == test_set["bikes_a_pred"]) & (test_set["bikes_a"] == False)]) / len(test_set[test_set["bikes_a"] == False]))
# Out:
# /tmp/ipykernel_25649/2623517162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_set["bikes_a_pred"] = test_set["num_bikes_available"]>0
# (0.9650410940781532, 0.9304851085966965)

# %%
confusion_matrix(test_set["bikes_a"], test_set["bikes_a_pred"], labels=[True, False])
# Out:
# array([[220240,   5225],
#        [  5345,  71545]])

# %%
confusion_matrix(test_set["bikes_a"], test_set["bikes_a_pred"], labels=[True, False], normalize="true")
# Out:
# array([[0.97682567, 0.02317433],
#        [0.06951489, 0.93048511]])

# %%
nn_feat_transf = ColumnTransformer([("ohe",  OneHotEncoder(sparse=False), ["hour", "dow"]),
                                    ("ss",  StandardScaler(),
                                    ["num_bikes_available", "num_bikes_disabled", "num_docks_available", "num_docks_disabled", "minutes_bt_check"])])

# %%
train_set_feats = nn_feat_transf.fit_transform(train_set)
val_set_feats = nn_feat_transf.transform(val_set)
test_set_feats = nn_feat_transf.transform(test_set)

# %%
from tensorflow import keras

nn_model = keras.Sequential(
    [
        keras.layers.Dense(
            128, activation="relu", input_shape=(train_set_feats.shape[-1],)
        ),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.25),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.25),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)
# Out:
# 2022-11-26 12:02:29.429936: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-26 12:02:29.668698: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-11-26 12:02:29.702679: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-26 12:02:29.702693: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-26 12:02:30.583755: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-11-26 12:02:30.583899: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-11-26 12:02:30.583907: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-11-26 12:02:31.387507: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-11-26 12:02:31.387714: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-26 12:02:31.387727: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (xeli): /proc/driver/nvidia/version does not exist
# 2022-11-26 12:02:31.388514: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
metrics = [
    keras.metrics.FalseNegatives(name="fn"),
    keras.metrics.FalsePositives(name="fp"),
    keras.metrics.TrueNegatives(name="tn"),
    keras.metrics.TruePositives(name="tp"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]

nn_model.compile(
    optimizer=keras.optimizers.Adam(1e-3), loss="binary_crossentropy", metrics=metrics
)

nn_model.fit(
    train_set_feats,
    train_set["bikes_a"],
    batch_size=2048,
    epochs=30,
    verbose=2,
    validation_data=(val_set_feats, val_set["bikes_a"]),
    class_weight={0: 1, 1: 500},
)
# Out:
# Epoch 1/30
# 384/384 - 5s - loss: 8.2635 - fn: 2517.0000 - fp: 213324.0000 - tn: 981.0000 - tp: 568263.0000 - precision: 0.7271 - recall: 0.9956 - val_loss: 0.9248 - val_fn: 0.0000e+00 - val_fp: 26025.0000 - val_tn: 0.0000e+00 - val_tp: 138210.0000 - val_precision: 0.8415 - val_recall: 1.0000 - 5s/epoch - 12ms/step
# Epoch 2/30
# 384/384 - 4s - loss: 1.4531 - fn: 0.0000e+00 - fp: 214276.0000 - tn: 29.0000 - tp: 570780.0000 - precision: 0.7271 - recall: 1.0000 - val_loss: 0.7627 - val_fn: 0.0000e+00 - val_fp: 26025.0000 - val_tn: 0.0000e+00 - val_tp: 138210.0000 - val_precision: 0.8415 - val_recall: 1.0000 - 4s/epoch - 9ms/step
# Epoch 3/30
# 384/384 - 5s - loss: 1.0962 - fn: 2.0000 - fp: 179479.0000 - tn: 34826.0000 - tp: 570778.0000 - precision: 0.7608 - recall: 1.0000 - val_loss: 0.6855 - val_fn: 0.0000e+00 - val_fp: 23205.0000 - val_tn: 2820.0000 - val_tp: 138210.0000 - val_precision: 0.8562 - val_recall: 1.0000 - 5s/epoch - 12ms/step
# Epoch 4/30
# 384/384 - 4s - loss: 0.9629 - fn: 4.0000 - fp: 139979.0000 - tn: 74326.0000 - tp: 570776.0000 - precision: 0.8031 - recall: 1.0000 - val_loss: 0.7306 - val_fn: 0.0000e+00 - val_fp: 23445.0000 - val_tn: 2580.0000 - val_tp: 138210.0000 - val_precision: 0.8550 - val_recall: 1.0000 - 4s/epoch - 10ms/step
# Epoch 5/30
# 384/384 - 4s - loss: 0.8848 - fn: 2.0000 - fp: 129905.0000 - tn: 84400.0000 - tp: 570778.0000 - precision: 0.8146 - recall: 1.0000 - val_loss: 0.6203 - val_fn: 23.0000 - val_fp: 21644.0000 - val_tn: 4381.0000 - val_tp: 138187.0000 - val_precision: 0.8646 - val_recall: 0.9998 - 4s/epoch - 10ms/step
# Epoch 6/30
# 384/384 - 3s - loss: 0.8276 - fn: 5.0000 - fp: 117239.0000 - tn: 97066.0000 - tp: 570775.0000 - precision: 0.8296 - recall: 1.0000 - val_loss: 0.6245 - val_fn: 62.0000 - val_fp: 20764.0000 - val_tn: 5261.0000 - val_tp: 138148.0000 - val_precision: 0.8693 - val_recall: 0.9996 - 3s/epoch - 9ms/step
# Epoch 7/30
# 384/384 - 4s - loss: 0.7988 - fn: 6.0000 - fp: 109230.0000 - tn: 105075.0000 - tp: 570774.0000 - precision: 0.8394 - recall: 1.0000 - val_loss: 0.6393 - val_fn: 179.0000 - val_fp: 20279.0000 - val_tn: 5746.0000 - val_tp: 138031.0000 - val_precision: 0.8719 - val_recall: 0.9987 - 4s/epoch - 10ms/step
# Epoch 8/30
# 384/384 - 3s - loss: 0.7755 - fn: 8.0000 - fp: 104588.0000 - tn: 109717.0000 - tp: 570772.0000 - precision: 0.8451 - recall: 1.0000 - val_loss: 0.6405 - val_fn: 146.0000 - val_fp: 21356.0000 - val_tn: 4669.0000 - val_tp: 138064.0000 - val_precision: 0.8660 - val_recall: 0.9989 - 3s/epoch - 8ms/step
# Epoch 9/30
# 384/384 - 3s - loss: 0.7539 - fn: 4.0000 - fp: 100886.0000 - tn: 113419.0000 - tp: 570776.0000 - precision: 0.8498 - recall: 1.0000 - val_loss: 0.6226 - val_fn: 162.0000 - val_fp: 19619.0000 - val_tn: 6406.0000 - val_tp: 138048.0000 - val_precision: 0.8756 - val_recall: 0.9988 - 3s/epoch - 9ms/step
# Epoch 10/30
# 384/384 - 3s - loss: 0.7468 - fn: 7.0000 - fp: 100182.0000 - tn: 114123.0000 - tp: 570773.0000 - precision: 0.8507 - recall: 1.0000 - val_loss: 0.6676 - val_fn: 177.0000 - val_fp: 21618.0000 - val_tn: 4407.0000 - val_tp: 138033.0000 - val_precision: 0.8646 - val_recall: 0.9987 - 3s/epoch - 8ms/step
# Epoch 11/30
# 384/384 - 3s - loss: 0.7276 - fn: 7.0000 - fp: 97289.0000 - tn: 117016.0000 - tp: 570773.0000 - precision: 0.8544 - recall: 1.0000 - val_loss: 0.6014 - val_fn: 383.0000 - val_fp: 18240.0000 - val_tn: 7785.0000 - val_tp: 137827.0000 - val_precision: 0.8831 - val_recall: 0.9972 - 3s/epoch - 8ms/step
# Epoch 12/30
# 384/384 - 5s - loss: 0.7189 - fn: 7.0000 - fp: 96431.0000 - tn: 117874.0000 - tp: 570773.0000 - precision: 0.8555 - recall: 1.0000 - val_loss: 0.6806 - val_fn: 215.0000 - val_fp: 20527.0000 - val_tn: 5498.0000 - val_tp: 137995.0000 - val_precision: 0.8705 - val_recall: 0.9984 - 5s/epoch - 14ms/step
# Epoch 13/30
# 384/384 - 3s - loss: 0.7082 - fn: 3.0000 - fp: 95670.0000 - tn: 118635.0000 - tp: 570777.0000 - precision: 0.8564 - recall: 1.0000 - val_loss: 0.6676 - val_fn: 269.0000 - val_fp: 19934.0000 - val_tn: 6091.0000 - val_tp: 137941.0000 - val_precision: 0.8737 - val_recall: 0.9981 - 3s/epoch - 8ms/step
# Epoch 14/30
# 384/384 - 4s - loss: 0.7087 - fn: 8.0000 - fp: 96287.0000 - tn: 118018.0000 - tp: 570772.0000 - precision: 0.8557 - recall: 1.0000 - val_loss: 0.6577 - val_fn: 272.0000 - val_fp: 18956.0000 - val_tn: 7069.0000 - val_tp: 137938.0000 - val_precision: 0.8792 - val_recall: 0.9980 - 4s/epoch - 10ms/step
# Epoch 15/30
# 384/384 - 3s - loss: 0.6971 - fn: 3.0000 - fp: 94478.0000 - tn: 119827.0000 - tp: 570777.0000 - precision: 0.8580 - recall: 1.0000 - val_loss: 0.6772 - val_fn: 278.0000 - val_fp: 19287.0000 - val_tn: 6738.0000 - val_tp: 137932.0000 - val_precision: 0.8773 - val_recall: 0.9980 - 3s/epoch - 8ms/step
# Epoch 16/30
# 384/384 - 3s - loss: 0.6896 - fn: 5.0000 - fp: 94709.0000 - tn: 119596.0000 - tp: 570775.0000 - precision: 0.8577 - recall: 1.0000 - val_loss: 0.6486 - val_fn: 275.0000 - val_fp: 19101.0000 - val_tn: 6924.0000 - val_tp: 137935.0000 - val_precision: 0.8784 - val_recall: 0.9980 - 3s/epoch - 8ms/step
# Epoch 17/30
# 384/384 - 3s - loss: 0.6867 - fn: 6.0000 - fp: 93337.0000 - tn: 120968.0000 - tp: 570774.0000 - precision: 0.8595 - recall: 1.0000 - val_loss: 0.6618 - val_fn: 284.0000 - val_fp: 19931.0000 - val_tn: 6094.0000 - val_tp: 137926.0000 - val_precision: 0.8737 - val_recall: 0.9979 - 3s/epoch - 8ms/step
# Epoch 18/30
# 384/384 - 3s - loss: 0.6871 - fn: 4.0000 - fp: 94817.0000 - tn: 119488.0000 - tp: 570776.0000 - precision: 0.8575 - recall: 1.0000 - val_loss: 0.6683 - val_fn: 267.0000 - val_fp: 19089.0000 - val_tn: 6936.0000 - val_tp: 137943.0000 - val_precision: 0.8784 - val_recall: 0.9981 - 3s/epoch - 9ms/step
# Epoch 19/30
# 384/384 - 3s - loss: 0.6858 - fn: 4.0000 - fp: 93676.0000 - tn: 120629.0000 - tp: 570776.0000 - precision: 0.8590 - recall: 1.0000 - val_loss: 0.6734 - val_fn: 270.0000 - val_fp: 18876.0000 - val_tn: 7149.0000 - val_tp: 137940.0000 - val_precision: 0.8796 - val_recall: 0.9980 - 3s/epoch - 9ms/step
# Epoch 20/30
# 384/384 - 3s - loss: 0.6801 - fn: 5.0000 - fp: 92642.0000 - tn: 121663.0000 - tp: 570775.0000 - precision: 0.8604 - recall: 1.0000 - val_loss: 0.6825 - val_fn: 151.0000 - val_fp: 20807.0000 - val_tn: 5218.0000 - val_tp: 138059.0000 - val_precision: 0.8690 - val_recall: 0.9989 - 3s/epoch - 9ms/step
# Epoch 21/30
# 384/384 - 3s - loss: 0.6711 - fn: 3.0000 - fp: 92995.0000 - tn: 121310.0000 - tp: 570777.0000 - precision: 0.8599 - recall: 1.0000 - val_loss: 0.6385 - val_fn: 297.0000 - val_fp: 18483.0000 - val_tn: 7542.0000 - val_tp: 137913.0000 - val_precision: 0.8818 - val_recall: 0.9979 - 3s/epoch - 9ms/step
# Epoch 22/30
# 384/384 - 3s - loss: 0.6764 - fn: 5.0000 - fp: 92837.0000 - tn: 121468.0000 - tp: 570775.0000 - precision: 0.8601 - recall: 1.0000 - val_loss: 0.7176 - val_fn: 279.0000 - val_fp: 19813.0000 - val_tn: 6212.0000 - val_tp: 137931.0000 - val_precision: 0.8744 - val_recall: 0.9980 - 3s/epoch - 8ms/step
# Epoch 23/30
# 384/384 - 3s - loss: 0.6771 - fn: 4.0000 - fp: 93907.0000 - tn: 120398.0000 - tp: 570776.0000 - precision: 0.8587 - recall: 1.0000 - val_loss: 0.7162 - val_fn: 269.0000 - val_fp: 19574.0000 - val_tn: 6451.0000 - val_tp: 137941.0000 - val_precision: 0.8757 - val_recall: 0.9981 - 3s/epoch - 8ms/step
# Epoch 24/30
# 384/384 - 3s - loss: 0.6642 - fn: 3.0000 - fp: 91768.0000 - tn: 122537.0000 - tp: 570777.0000 - precision: 0.8615 - recall: 1.0000 - val_loss: 0.6435 - val_fn: 272.0000 - val_fp: 18716.0000 - val_tn: 7309.0000 - val_tp: 137938.0000 - val_precision: 0.8805 - val_recall: 0.9980 - 3s/epoch - 8ms/step
# Epoch 25/30
# 384/384 - 3s - loss: 0.6587 - fn: 1.0000 - fp: 90430.0000 - tn: 123875.0000 - tp: 570779.0000 - precision: 0.8632 - recall: 1.0000 - val_loss: 0.7477 - val_fn: 297.0000 - val_fp: 19629.0000 - val_tn: 6396.0000 - val_tp: 137913.0000 - val_precision: 0.8754 - val_recall: 0.9979 - 3s/epoch - 7ms/step
# Epoch 26/30
# 384/384 - 3s - loss: 0.6694 - fn: 6.0000 - fp: 92621.0000 - tn: 121684.0000 - tp: 570774.0000 - precision: 0.8604 - recall: 1.0000 - val_loss: 0.6882 - val_fn: 269.0000 - val_fp: 18672.0000 - val_tn: 7353.0000 - val_tp: 137941.0000 - val_precision: 0.8808 - val_recall: 0.9981 - 3s/epoch - 7ms/step
# Epoch 27/30
# 384/384 - 3s - loss: 0.6636 - fn: 4.0000 - fp: 91373.0000 - tn: 122932.0000 - tp: 570776.0000 - precision: 0.8620 - recall: 1.0000 - val_loss: 0.7412 - val_fn: 279.0000 - val_fp: 20148.0000 - val_tn: 5877.0000 - val_tp: 137931.0000 - val_precision: 0.8725 - val_recall: 0.9980 - 3s/epoch - 8ms/step
# Epoch 28/30
# 384/384 - 3s - loss: 0.6638 - fn: 4.0000 - fp: 92011.0000 - tn: 122294.0000 - tp: 570776.0000 - precision: 0.8612 - recall: 1.0000 - val_loss: 0.6415 - val_fn: 284.0000 - val_fp: 18492.0000 - val_tn: 7533.0000 - val_tp: 137926.0000 - val_precision: 0.8818 - val_recall: 0.9979 - 3s/epoch - 7ms/step
# Epoch 29/30
# 384/384 - 3s - loss: 0.6687 - fn: 5.0000 - fp: 92563.0000 - tn: 121742.0000 - tp: 570775.0000 - precision: 0.8605 - recall: 1.0000 - val_loss: 0.7008 - val_fn: 284.0000 - val_fp: 19213.0000 - val_tn: 6812.0000 - val_tp: 137926.0000 - val_precision: 0.8777 - val_recall: 0.9979 - 3s/epoch - 8ms/step
# Epoch 30/30
# 384/384 - 3s - loss: 0.6617 - fn: 3.0000 - fp: 91958.0000 - tn: 122347.0000 - tp: 570777.0000 - precision: 0.8612 - recall: 1.0000 - val_loss: 0.6976 - val_fn: 318.0000 - val_fp: 19392.0000 - val_tn: 6633.0000 - val_tp: 137892.0000 - val_precision: 0.8767 - val_recall: 0.9977 - 3s/epoch - 7ms/step

# %%
test_set["bikes_a_pred"] = nn_model.predict(test_set_feats)
# Out:
# 9449/9449 [==============================] - 6s 584us/step
# /tmp/ipykernel_25649/2808917452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_set["bikes_a_pred"] = nn_model.predict(test_set_feats)

# %%
from sklearn.metrics import roc_curve,roc_auc_score

fpr , tpr , thresholds = roc_curve(test_set["bikes_a"], test_set["bikes_a_pred"])
roc_auc_score(test_set["bikes_a"], test_set["bikes_a_pred"])
# Out:
# 0.9731831627967711

# %%
import matplotlib.pyplot as plt

plt.plot(fpr,tpr) 
plt.axis([0,1,0,1]) 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.show()

# %%
test_set["bikes_a_pred"] = test_set["bikes_a_pred"]>0.9
# Out:
# /tmp/ipykernel_25649/2066434752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_set["bikes_a_pred"] = test_set["bikes_a_pred"]>0.9

# %%
confusion_matrix(test_set["bikes_a"], test_set["bikes_a_pred"], labels=[True, False])
# Out:
# array([[224496,    969],
#        [ 40771,  36119]])

# %%
confusion_matrix(test_set["bikes_a"], test_set["bikes_a_pred"], labels=[True, False], normalize="true")
# Out:
# array([[0.99570222, 0.00429778],
#        [0.53025101, 0.46974899]])

# %% [markdown]
# Con este modelo bajamos a 0.9 la tasa de falsos positivos.

# %% [markdown]
# # Create model using a scikit pipeline without dataframes

# %%
from scikeras.wrappers import KerasClassifier
from sklearn.pipeline import Pipeline

# %%
def create_model(hidden_layer_dim, drop_out_p, meta):
    X_shape_ = meta["X_shape_"]
    nn_model = keras.Sequential([
        keras.layers.Dense(hidden_layer_dim, activation="relu", input_shape=X_shape_[1:]),
        keras.layers.Dense(hidden_layer_dim, activation="relu"),
        keras.layers.Dropout(drop_out_p),
        keras.layers.Dense(hidden_layer_dim, activation="relu"),
        keras.layers.Dropout(drop_out_p),
        keras.layers.Dense(1, activation="sigmoid")
        ]
    )
    return nn_model

keras_cls = KerasClassifier(
    create_model,
    hidden_layer_dim=128,
    drop_out_p=0.25,
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    batch_size=2048,
    epochs=30,
    verbose=0,
    class_weight={0: 1, 1: 500},
)

# %%
FEATURES_ORDER = ["hour", "dow", "num_bikes_available", "num_bikes_disabled", "num_docks_available", "num_docks_disabled", "minutes_bt_check"]
keras_pipeline = Pipeline([
    ('preprocess', ColumnTransformer([("ohe",  OneHotEncoder(sparse=False), [0, 1]), ("ss",  StandardScaler(), slice(2,7))])),
    ('keras_cls', keras_cls),
])

# %%
X_train = train_set[:10000][FEATURES_ORDER].values
y_train = train_set[:10000]["bikes_a"].values
keras_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('ohe',
#                                                   OneHotEncoder(sparse=False),
#                                                   [0, 1]),
#                                                  ('ss', StandardScaler(),
#                                                   slice(2, 7, None))])),
#                 ('keras_cls',
#                  KerasClassifier(batch_size=2048, class_weight={0: 1, 1: 500}, drop_out_p=0.25, epochs=30, hidden_layer_dim=128, loss='binary_crossentropy', model=<function create_model at 0x7f0e6c255bd0>, optimizer=<keras.optimizers.optimizer_experimental.adam.Adam object at 0x7f0e6c217be0>, verbose=0))])

# %%
keras_pipeline.predict_proba(test_set[:3][FEATURES_ORDER].values)
# Out:
# array([[0.00276625, 0.99723375],
#        [0.00276625, 0.99723375],
#        [0.00276625, 0.99723375]], dtype=float32)

# %% [markdown]
# ### Dump and load model

# %%
import joblib

# %%
# joblib.dump(keras_pipeline, 'current_model.joblib')
# loaded_model = joblib.load('current_model.joblib')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
FEATURES_ORDER = ["hour", "dow", "num_bikes_available", "num_bikes_disabled", "num_docks_available", "num_docks_disabled", "minutes_bt_check"]
nn_pipeline = Pipeline([
    ('preprocess', ColumnTransformer([("ohe",  OneHotEncoder(sparse=False), [0, 1]), ("ss",  StandardScaler(), slice(2,7))])),
    ('rf_cls', RandomForestClassifier(n_estimators=200, class_weight={0: 1, 1: 500})),
])

# %%
X_train = train_set[:10000][FEATURES_ORDER].values
y_train = train_set[:10000]["bikes_a"].values
nn_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('ohe',
#                                                   OneHotEncoder(sparse=False),
#                                                   [0, 1]),
#                                                  ('ss', StandardScaler(),
#                                                   slice(2, 7, None))])),
#                 ('rf_cls',
#                  RandomForestClassifier(class_weight={0: 1, 1: 500},
#                                         n_estimators=200))])

# %%
joblib.dump(nn_pipeline, 'current_model.joblib')
loaded_model = joblib.load('current_model.joblib')

# %%
loaded_model.predict_proba(test_set[:3][FEATURES_ORDER].values)
# Out:
# array([[0.09500766, 0.90499234],
#        [0.09500766, 0.90499234],
#        [0.09500766, 0.90499234]])
